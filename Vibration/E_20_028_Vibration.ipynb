# %% [markdown]
# <a href="https://colab.research.google.com/github/Imesh-Isuranga/ME-422-Group-B1/blob/main/Vibration/E_20_028_Vibration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## E/20/028

# %% [markdown]
# ## **Experiment 1: Introduction to the Equipment**

# %% [markdown]
# ### Procedure 1 - Free Vibration Displacement

# %% [markdown]
# Apparatus was setup as below under free vibartion
#
# ![image.png](data:image/png;base64,...)
#
#
# VDAS software was setup as below and got the displacment reading (curve)
#
# ![Screenshot 2026-01-26 160009.png](data:image/png;base64,...)
#
# The recieved displacemnt curve as followed wich showed a contannt natural frequency as followed around 6.67 Hz
#
# ![1.1.png](data:image/png;base64,...)

# %% [markdown]
# ### Procedure 2 - Displacement 1st Derivative (Velocity)

# %% [markdown]
# Apparatus and VDAS was setup as below under free vibartion
#
#
# ![image.png](data:image/png;base64,...)
#
#
# The below figure show the result form the VDAS which indicate the both displacement and derived velocitty curves with a 90 degree phase shift
#
# ![1.2.png](data:image/png;base64,...)

# %% [markdown]
# ### Procedure 3 - Displacement 2nd Derivative (Acceleration)

# %% [markdown]
# Apparatus and VDAS was setup as below under free vibartion
#
#
# ![image.png](data:image/png;base64,...)
#
# The below figure shows the all displacement, derived velocity and deriived acceleration plots with a 180 degree phase shift from displacement
#
# ![1.3.png](data:image/png;base64,...)

# %% [markdown]
# ### Procedure 4 - Measured Acceleration

# %% [markdown]
# Apparatus and VDAS was setup as below under free vibartion
#
# ![image.png](data:image/png;base64,...)
#
# The below figure shows the derived acceleration from displacement vs the measured acceleration which shows a close similarity between shape and phase and amplitude
#
# ![1.4.png](data:image/png;base64,...)

# %% [markdown]
# ### Procedure 5 - Forced Vibration Displacement

# %% [markdown]
# Apparatus and VDAS was setup as below under forced vibartion
#
# ![image.png](data:image/png;base64,...)
#
# The below figure shows the result from the forced vibration under 6.59 Hz exicted by the motor, adjust closer to the beam natural frequencty fiound earlier which give a max amplitue of aorund 20 mm.
#
# ![1.5.png](data:image/png;base64,...)

# %% [markdown]
# ### Procedure 6 - Damping Ratio

# %% [markdown]
# Apparatus and VDAS was setup as below under free vibartion
#
# ![image.png](data:image/png;base64,...)
#
# The below figure shows thee response recorded in VDAS approximately over 6 seconds, and fit the undamped model which give a damping ratio $\zeta$ = 0.001
#
# ![1.6.png](data:image/png;base64,...)

# %% [markdown]
# <a href="https://colab.research.google.com/github/Imesh-Isuranga/ME-422-Group-B1/blob/main/Vibration/E_20_056_Vibrations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 1
#
# ### Activity 1
#
# Derive the 2-dof freedom model that will capture the first two dominant modes of small amplitude vibration of the system.

# %% [markdown]
# Beam will oscillate about the left hand pivot through an angle θ.
#
# Using small angle approximation,
#
# sin θ ≅ θ
#
# Summing the moments around the pivot,
#
# \begin{align}
# &I_A\ddot{\theta}+kx_sl_{spring}=0\\
# \\
# I_A&=I_{beam}+I_{exciter}+I_{spring}\\
# I_{beam} &= \frac{1}{12}m_{beam}I_{beam}^2+m_{beam}(\frac{l_{beam}}{2})^2= \frac{1}{3}m_{beam}I_{beam}^2\\
# I_{exciter} &= m_{exciter}I_{exciter}^2\\
# \end{align}
#
# Note: This theory assumes the central mass act as a point load.
#
# The theory allows for proportion of the sprong mass - the part which actually move and contribute to overall mass of the system.According to Rayleighs theory, this is equal to 1/3 the mass
# of the spring. The fixing between the spring and the beam also needs to be allowed for:
#
# \begin{align}
# I_{spring}=(\frac{m_{spring}}{3}+m_{fixing})l_{spring}^2
# \end{align}
#
# using small angle approximation,
#
# \begin{align}
# x_s=θl_{spring}\\
# \\
# I_A\ddot{\theta}+kl_{spring}^2θ=0
# \end{align}
#
# General Solution:
#
# \begin{align}
# θ=Acos(
# \end{align}

# %% [markdown]
# <a href="https://colab.research.google.com/github/Imesh-Isuranga/ME-422-Group-B1/blob/main/Vibration/E_20_128.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# VIBRATION LAB - WEEK 01-04

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The experimental arrangement comprises a rigid beam that is hinged at one end, enabling it to rotate freely about a fixed pivot. A rotating unbalanced motor is installed at a specified location along the beam to act as a source of periodic (harmonic) excitation. The opposite end of the beam is elastically supported by a vertical spring that connects it to a rigid frame, allowing vertical displacement while providing restoring force.
#
# The beam possesses a continuous mass distribution along its length, and additional concentrated masses arise from the exciter motor, the spring assembly, and the attachment at the supported end. The system geometry is characterized by the total beam length, the distance of the exciter from the pivot, and the location of the spring connection.
#
# This setup enables controlled investigation of both free and forced vibration responses of the beam–spring system, making it suitable for studying dynamic behavior such as natural frequencies, mode shapes, and resonance effects.

# %% [markdown]
# For a slender beam undergoing small transverse deflections, the dynamic behavior can be accurately represented using the Euler–Bernoulli beam theory, treating the beam as a continuous elastic system. The transverse vibration of the beam is governed by the following partial differential equation:
#
# $$ {\rho A}{{\partial^2 y} \over {\partial t^2}} + c{{\partial y} \over {\partial t}}+EI{{\partial^4 y} \over {\partial x^4}}+P {{\partial^2 y} \over {\partial x^2}}=f(t,x) $$
#
# In this expression,
# 𝑦
# (
# 𝑥
# ,
# 𝑡
# )
#  denotes the transverse displacement of the beam at position
# 𝑥
# x and time
# 𝑡
# . The term
# 𝜌
# 𝐴
#  represents the mass per unit length, where
# 𝜌
# is the material density and
# 𝐴
# is the cross-sectional area. The bending stiffness of the beam is given by
# 𝐸
# 𝐼
# , with
# 𝐸
# being Young’s modulus and
# 𝐼
# the second moment of area.
# The parameter
# 𝑃
# accounts for the effect of an axial compressive load acting along the beam, while
# 𝑐
# represents the distributed viscous damping coefficient. The right-hand side term
# 𝑓
# (
# 𝑥
# ,
# 𝑡
# )
# corresponds to the externally applied transverse force per unit length, which may vary with both position and time.
# Since $P = 0$ for this case, the above PDE can be reduced to:
#
# $$
# {\rho A}{{\partial^2 y} \over {\partial t^2}} + c{{\partial y} \over {\partial t}}+EI{{\partial^4 y} \over {\partial x^4}}=f(t,x)
# $$

# %% [markdown]
# The solutions of the above PDE that satisfy the boundary conditions of a pinned-free beam.
#
# \begin{align*}y(0,t)&=0,\:\:\:\:\:\:\: {\partial^3 y \over \partial x^3}(l_{beam},t)=0,\\{\partial^2 y \over \partial x^2}(0,t)&=0,\:\:\:\:\:\:\: {\partial^2 y \over \partial x^2}(l_{beam},t)=0,\end{align*}

# %% [markdown]
# **FREE VIBRATION ANALYSIS FOR MODE SHAPES :**

# %% [markdown]
# Define $\mathfrak{F}$ as the set of functions on
# [0,𝐿] that are four times differentiable. Consider a linear operator
#
# \begin{align}H&=\frac{EI} {\rho A}{{\partial^4 } \over {\partial x^4}}
# \end{align}
#
# which maps an admissible deflection field to the corresponding acceleration term associated with bending. With this notation, the governing PDE takes the operator form
#
# \begin{align*}
# {{\partial^2 y} \over {\partial t^2}} + C{{\partial y} \over {\partial t}}+Hy&=q(t,x)
# \end{align*}
#
# where $c = C \rho A$ and $f(t) = \rho A q(t)$
#
# $H$ maps a transverse deflection shape to the acceleration caused purely by beam bending, subject to the beam’s boundary conditions. Let $H$ have distinct positive eignevalues $\{\omega_k^2\}_{k=1}^\infty$ with corrsponding eigenvectors $\{\psi_k\}_{k=1}^\infty$ i.e. mode shapes.
#
# Then, the eigenvalue problem can be defined as:
#
# \begin{align*}
# H \psi_k(x) &= \omega_k^2 \psi(x)
# \end{align*}
#
# Substituting $(1)$, we get:
#
# \begin{align*}
# \frac{EI}{\rho A} \frac{\partial^4 \psi_k(x)}{\partial x^4} &= \omega_k^2 \psi_k(x) \\
# \frac{\partial^4 \psi_k(x)}{\partial x^4} &= \frac{\rho A \, \omega_k^2}{EI} \psi_k(x)  \\
# \frac{\partial^4 \psi_k(x)}{\partial x^4} &= \beta_k^4 \psi_k(x)
# \end{align*}
#
# where $\beta_k^4 = \frac{\rho A \, \omega_k^2}{EI}$

# %% [markdown]
# The general solution of the fourth-order differential equation $(1)$ is
#
# \begin{align*}
# \psi_k(x) = A_k \cosh(\beta_k x) + B_k \sinh(\beta_k x) + C_k \cos(\beta_k x) + D_k \sin(\beta_k x)
# \end{align*}
#
# where $A_k$, $B_k$, $C_k$, $D_k$ are constants determined from boundary conditions.
#
# Boundary conditions at pinned-end:
#
# \begin{align*}
# \psi_k(0) &= 0 \quad \Rightarrow \quad A_k + C_k = 0 \\
# \psi_k''(0) &= 0 \quad \Rightarrow \quad A_k - C_k = 0
# \end{align*}
#
# Solving this, we get:
#
# $$
# A_k = C_k = 0
# $$
#
# Hence
#
# \begin{align*}
# \psi_k(x) = B_k \sinh(\beta_k x) + D_k \sin(\beta_k x)
# \end{align*}
#
# Boundary conditions at free-end:
#
# \begin{align*}
# \psi_k''(l_{beam}) = 0 \Rightarrow B_k \sinh(\beta_k l_{beam}) - D_k \sin(\beta_k l_{beam}) = 0 \\
# \psi_k'''(l_{beam}) = 0 \Rightarrow B_k \cosh(\beta_k l_{beam}) - D_k \cos(\beta_k l_{beam}) = 0
# \end{align*}
#
# For a non-trivial solution $(B_k, D_k) \neq (0,0)$, this simplifies to:
#
# $$
# \tan(\beta_k l_{beam}) = \tanh(\beta_k l_{beam})
# $$
#
# Let us solve the above transcendental equation numerically to find $\beta_k$ for $k \in \mathbb{N}$.

# %% [markdown]
# The general solution of the fourth-order differential equation $(1)$ is
#
# \begin{align*}
# \psi_k(x) = A_k \cosh(\beta_k x) + B_k \sinh(\beta_k x) + C_k \cos(\beta_k x) + D_k \sin(\beta_k x)
# \end{align*}
#
# where $A_k$, $B_k$, $C_k$, $D_k$ are constants determined from boundary conditions.
#
# Boundary condition at base-end:
#
# $$
# \psi_k(0) = 0 \quad \Rightarrow \quad A_k + C_k = 0
# $$
#
# <br>
#
# \begin{align*}
# \psi_k'(0) &= \beta_k(B_k+D_k) \\
# \psi_k''(0) &= \beta_k^2(A_k-C_k)
# \end{align*}
#
# Noting that $C_k = -A_k$, substitute $\psi_k'(0)$ and $\psi_k''(0)$ to,
#
# \begin{align*}
# EI \beta_k^2(A_k-C_k) - k_{\theta}\beta_k(B_k+D_k) &= 0 \\
# 2EI \beta_k^2A_k - k_{\theta}\beta_k(B_k+D_k) &= 0
# \end{align*}
#
# Boundary conditions at free-end:
#
# \begin{align*}
# \psi_k''(l_{beam}) = 0 & \Rightarrow
# & A_k(\cosh(\beta_k l_{beam}) + \cos(\beta_k l_{beam})) + B_k\sinh(\beta_k l_{beam}) - D_k\sin(\beta_k l_{beam})  = 0 \\
# \psi_k'''(l_{beam}) = 0 & \Rightarrow
# & A_k(\sinh(\beta_k l_{beam}) - \sin(\beta_k l_{beam})) + B_k\cosh(\beta_k l_{beam}) - D_k \cos(\beta_k l_{beam}) = 0
# \end{align*}
#
# <br>
#
# The above three equations form a linear homogeneous system.
#
# $$
# \mathbf{H}(\beta_k)\begin{bmatrix} A_k \\ B_k \\ D_k \end{bmatrix} = \mathbf{0}
# $$
#
# where $\mathbf{H}(\beta_k) \in \mathbb{M_{3x3}}$
#
# For non-trivial solutions, $\text{det}\,\mathbf{H}(\beta_k) = 0$. Let us solve the determinent numerically to find $\beta_k$ for $k \in \mathbb{N}$ and the linear homogeneous system to find $A_k$, $B_k$ and $D_k$

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from numpy.linalg import det as mat_det
from scipy.linalg import svd as svd_decomp
from scipy.integrate import quad
from scipy.optimize import brentq as root_brent
from scipy.linalg import eigh

# Characteristic determinant for identifying admissible betas
def characteristic_det(b, beam_len, flex_EI, rot_stiff):
    """Compute determinant of characteristic matrix for a given beta."""

    Lb = b * beam_len  # convenience term

    M = np.array([
        [2 * flex_EI * b**2,        -rot_stiff * b,         -rot_stiff * b],
        [np.cosh(Lb) + np.cos(Lb),   np.sinh(Lb),           -np.sin(Lb)],
        [np.sinh(Lb) - np.sin(Lb),   np.cosh(Lb),           -np.cos(Lb)]
    ])

    return mat_det(M)


# Locate roots (beta values) for given beam parameters
def locate_beta_values(beam_len, flex_EI, rot_stiff, num_modes=2, beta_limit=50.0):
    """Search for beta roots using sign-change bracketing."""

    discovered = []
    beta_scan = np.linspace(1e-4, beta_limit, 5000)

    det_vals = [characteristic_det(b, beam_len, flex_EI, rot_stiff) for b in beta_scan]

    for idx in range(len(beta_scan) - 1):
        if det_vals[idx] * det_vals[idx + 1] < 0:  # sign change → root interval

            root_val = root_brent(
                characteristic_det,
                beta_scan[idx],
                beta_scan[idx + 1],
                args=(beam_len, flex_EI, rot_stiff)
            )

            discovered.append(root_val)

            if len(discovered) >= num_modes:
                break

    return np.array(discovered)


# Determine modal shape constants A,B,C,D for given beta
def extract_mode_coeffs(b, beam_len, flex_EI, rot_stiff):
    """Compute coefficients for mode shape associated with beta."""

    Lb = b * beam_len

    M = np.array([
        [2 * flex_EI * b**2,        -rot_stiff * b,         -rot_stiff * b],
        [np.cosh(Lb) + np.cos(Lb),   np.sinh(Lb),           -np.sin(Lb)],
        [np.sinh(Lb) - np.sin(Lb),   np.cosh(Lb),           -np.cos(Lb)]
    ])

    # SVD: smallest singular vector corresponds to nullspace direction
    _, _, Vh = svd_decomp(M)
    vec = Vh[-1, :].copy()

    A_const, B_const, D_const = vec
    C_const = -A_const  # derived BC constraint

    return A_const, B_const, C_const, D_const

# %% [markdown]
# Then, the eigenvalues of $H$ are given by,
#
# $$
# \{\omega_k^2\}_{k=1}^\infty = \left\{\frac{EI}{\rho A}{\beta_k}^4\right\}_{k=1}^\infty
# $$
#
# and the eigenvectors/mode shapes of $H$ are given by,
#
# $$
# \{\psi_k\}_{k=1}^\infty = \left\{B_k \sinh(\beta_k x) + D_k \sin(\beta_k x)\right\}_{k=1}^\infty
# $$
#
# where $\frac{B_k}{D_k} = \frac{\sin{(\beta_k l_{beam})}}{\sinh{(\beta_k l_{beam})}} = \frac{\cos{(\beta_k l_{beam})}}{\cosh{(\beta_k l_{beam})}}$

# %% [markdown]
# Then, the eigenvalues of $H$ are given by,
#
# $$
# \{\omega_k^2\}_{k=1}^\infty = \left\{\frac{EI}{\rho A}{\beta_k}^4\right\}_{k=1}^\infty
# $$
#
# and the eigenvectors/mode shapes of $H$ are given by,
#
# $$
# \{\psi_k\}_{k=1}^\infty = \left\{A_k \cosh(\beta_k x) + B_k \sinh(\beta_k x) + C_k \cos(\beta_k x) + D_k \sin(\beta_k x)\right\}_{k=1}^\infty
# $$
#
# $A_k$, $B_k$, $C_k$ and $D_k$ to be found using numerical methods programmed in above functions.

# %% [markdown]
# **Forced Vibration Response using Modal Expansion:**

# %% [markdown]
# In the event the oscillator is turned on, a forced vibration takes place due to oscillating force $Q$.
#
# <center>
# <div style="text-align: center;">
#   <img src="https://github.com/chamudithamk/ME422-B2-Lab-Group/blob/main/Vibration/Images/E20198_Fig3.png?raw=1" width="60%" style="display: block; margin: 0 auto;">
#
#   <span style="display: block; text-align: center; margin-top: 5px;"><em>Figure 2: Oscillating Force of the Exciter (Reference: TM1016V User Guide 1022, Figure 18)</em></span></center>
# </div>

# %% [markdown]
# Under the assumption of no base excitation, the system response can be expressed as a set of independent forced and damped single-degree-of-freedom oscillators, one for each vibration mode $k$. This leads to the following representation:
#
# $$
# \ddot{y} + C\dot{y} + Hy = q(x,t)
# \quad \Rightarrow \quad
# m_k \ddot{z}_k + 2\zeta_k \omega_k m_k \dot{z}_k + m_k \omega_k^2 z_k
# = \langle\!\langle \psi_k(x), q(x,t) \rangle\!\rangle,
# $$
#
# where the modal damping ratio is defined as $\zeta_k = \dfrac{C}{2\omega_k}$ and the modal mass is given by
#
# $$
# m_k = \int_0^{l_{\text{beam}}} \rho A\, \psi_k^2(x)\, dx.
# $$
#
# The modal masses remove the arbitrary amplitude scaling introduced through the choice of coefficients $B_k$ and $D_k$ in the mode shape expressions.
#
# Solving the resulting decoupled ordinary differential equation for each mode $k$ results in the steady-state response
#
# $$
# z_k(t) = \chi_k(\Omega)\cos\!\left(\Omega t + \phi_k(\Omega)\right),
# $$
#
# where $\chi_k(\Omega)$ represents the steady-state amplitude and $\phi_k(\Omega)$ denotes the phase lag of the $k^{\text{th}}$ modal coordinate at the excitation frequency $\Omega$.

# %% [markdown]
# The resulting response of the beam, expressed in its infinite-dimensional form, can therefore be written as
#
# \begin{align*}
# y(t,x)
# = \sum_{k=1}^{\infty} z_k(t)\, \psi_k(x)
# = \sum_{k=1}^{\infty}
# \chi_k(\Omega)\cos\!\left(\Omega t + \phi_k(\Omega)\right)\psi_k(x).
# \end{align*}

# %% [markdown]
# **Reduction to 2-DOF Model with Localised Spring–Damper Attachment:**

# %% [markdown]
# Truncating the infinite-dimensional solution to the first two dominant modes, the displacement can be approximated as:
#
# \begin{align*}
# y(t,x) \approx \chi_1(\Omega) \cos(\Omega t + \phi_1(\Omega)) \, \psi_1(x)
# + \chi_2(\Omega) \cos(\Omega t + \phi_2(\Omega)) \, \psi_2(x)
# \end{align*}
#
# The corresponding 2-DOF system in matrix form is given by,
#
# \begin{align*}
# \underbrace{\begin{bmatrix} m_1 & 0 \\ 0 & m_2 \end{bmatrix}}_{M_\text{beam}}
# \begin{bmatrix} \ddot{z}_1 \\ \ddot{z}_2 \end{bmatrix}
# +
# \underbrace{\begin{bmatrix} 2 \zeta_1 \omega_1 m_1 & 0 \\ 0 & 2 \zeta_2 \omega_2 m_2 \end{bmatrix}}_{C_\text{beam}}
# \begin{bmatrix} \dot{z}_1 \\ \dot{z}_2 \end{bmatrix}
# +
# \underbrace{\begin{bmatrix} \omega_1^2 m_1 & 0 \\ 0 & \omega_2^2 m_2 \end{bmatrix}}_{K_\text{beam}}
# \begin{bmatrix} z_1 \\ z_2 \end{bmatrix}
# =
# \underbrace{\begin{bmatrix} Q \psi_1(l_{exciter}) \sin{(\Omega t)} \\[1mm] Q \psi_2(l_{exciter}) \sin{(\Omega t)} \end{bmatrix}}_{F_{exciter}}
# \end{align*}
#
#
# Let us now account for the spring and viscous damper attachments.

# %% [markdown]
# <center>
# <div style="text-align: center;">
#   <img src="https://github.com/Imesh-Isuranga/ME-422-Group-B1/blob/main/Vibration/Images/Fig2.png?raw=1" width="55%" style="display: block; margin: 0 auto;">
#
#   <span style="display: block; text-align: center; margin-top: 5px;"><em>Figure 3: Schematic Details of the Viscous Damper (Reference: TM1016V User Guide 1022, Figure 13)</em></span>
# </div></center>

# %% [markdown]
# **Part I: Consideration of Additional Masses**
#
# For accuracy, the theory allows for a proportion of the spring mass - that part which moves and contributes to the overall mass of the system. According to **Rayleigh's Theory**, this is equal to 1/3 the mass of the spring. The fixing between the spring and the beam also needs to be allowed for.
#
# $$
# m_{\text{eff}} = \frac{1}{3} m_{\text{spring}} + m_{\text{fixed}}
# $$
#
# The transverse acceleration at the attachment point is:
#
# \begin{align*}
# \ddot y(l_{\text{spring}},t)
# =
# \ddot z_1(t)\psi_1(l_{\text{spring}})
# + \ddot z_2(t)\psi_2(l_{\text{spring}})
# \end{align*}
#
# The inertia force exerted by the attached mass is:
#
# \begin{align*}
# F_{\text{inertia}}(t)
# =
# m_{\text{eff}}
# \ddot y(l_{\text{spring}},t)
# \end{align*}
#
# Modal force acting on each mode:
#
# $$
# F^{(m)}_k = F_{\text{inertia}}(t) \psi_k(l_{\text{spring}})
# $$
#
# Projecting this force onto the modal coordinates gives:
#
# \begin{align*}
# \begin{bmatrix}
# F^{(m)}_1 \\
# F^{(m)}_2
# \end{bmatrix}
# =
# M_{\text{spring}}
# \begin{bmatrix}
# \ddot z_1 \\
# \ddot z_2
# \end{bmatrix}
# \end{align*}
#
# where the additional mass matrix is
#
# \begin{align*}
# M_{\text{spring}}
# =
# m_{\text{eff}}
# \begin{bmatrix}
# \psi_1^2(l_{\text{spring}}) &
# \psi_1(l_{\text{spring}})\psi_2(l_{\text{spring}}) \\
# \psi_1(l_{\text{spring}})\psi_2(l_{\text{spring}}) &
# \psi_2^2(l_{\text{spring}})
# \end{bmatrix}
# \end{align*}
#
# Similarly, additional masses of damper and exciter can be written as:
#
# $$
# M_{\text{damper}} =
# m_{\text{damper}}
# \begin{bmatrix}
# \psi_1^2(l_{\text{damper}}) &
# \psi_1(l_{\text{damper}})\psi_2(l_{\text{damper}}) \\
# \psi_1(l_{\text{damper}})\psi_2(l_{\text{damper}}) &
# \psi_2^2(l_{\text{damper}})
# \end{bmatrix}
# $$
#
# $$
# M_{\text{exciter}} =
# m_{\text{exciter}}
# \begin{bmatrix}
# \psi_1^2(l_{\text{exciter}}) &
# \psi_1(l_{\text{exciter}})\psi_2(l_{\text{exciter}}) \\
# \psi_1(l_{\text{exciter}})\psi_2(l_{\text{exciter}}) &
# \psi_2^2(l_{\text{exciter}})
# \end{bmatrix}
# $$
#
# <br>
#
# **Part II: Consideration of Damper Attachment**

# %% [markdown]
# By applying the constitutive relation for a viscous damper,
#
# \begin{align*}
# F_{\text{damper}}(t) = c_{\text{damper}} \dot{y}(l_{\text{damper}},t)
# \end{align*}
#
# Using the two-mode approximation,
#
# \begin{align*}
# \dot y(l_{\text{damper}},t) = \dot z_1(t)\psi_1(l_{\text{damper}})+\dot z_2(t)\psi_2(l_{\text{damper}})
# \end{align*}
#
# The modal force acting on the $k^{\text{th}}$ mode is obtained by projection:
#
# \begin{align*}
# F^{(c)}_k(t) = c_{\text{damper}}\left(\dot{z_1}\psi_1(l_{\text{damper}}) +\dot{z_2}\psi_2(l_{\text{damper}})\right)\psi_k(l_{\text{damper}})
# \end{align*}
#
# This yields the matrix form:
#
# \begin{align*}
# \begin{bmatrix}
# F^{(c)}_1 \\
# F^{(c)}_2
# \end{bmatrix} = C_{\text{damper}}
# \begin{bmatrix}
# \dot z_1 \\
# \dot z_2
# \end{bmatrix}
# \end{align*}
#
# where
#
# \begin{align*}
# C_{\text{damper}} =
# c_{\text{damper}}
# \begin{bmatrix}
# \psi_1^2(l_{\text{damper}}) &
# \psi_1(l_{\text{damper}})\psi_2(l_{\text{damper}}) \\
# \psi_1(l_{\text{damper}})\psi_2(l_{\text{damper}}) &
# \psi_2^2(l_{\text{damper}})
# \end{bmatrix}
# \end{align*}
#
# Dynamic and inertial contributions of spring, damper and exciter now can be included the 2-DOF system.

# %% [markdown]
# Applying the constitutive law for a linear viscous damper, the damping force can be expressed as
#
# \begin{align*}
# F_{\text{damper}}(t) = c_{\text{damper}}\, \dot{y}\!\left(l_{\text{damper}}, t\right).
# \end{align*}
#
# Under the two-mode approximation, the velocity at the damper location is given by
#
# \begin{align*}
# \dot{y}\!\left(l_{\text{damper}}, t\right)
# = \dot{z}_1(t)\, \psi_1\!\left(l_{\text{damper}}\right)
# + \dot{z}_2(t)\, \psi_2\!\left(l_{\text{damper}}\right).
# \end{align*}
#
# The damping force contribution to the $k^{\text{th}}$ modal equation is obtained by projecting the physical force onto the corresponding mode shape, yielding
#
# \begin{align*}
# F_k^{(c)}(t)
# = c_{\text{damper}}
# \left(
# \dot{z}_1 \psi_1\!\left(l_{\text{damper}}\right)
# + \dot{z}_2 \psi_2\!\left(l_{\text{damper}}\right)
# \right)
# \psi_k\!\left(l_{\text{damper}}\right).
# \end{align*}
#
# This can be written compactly in matrix form as
#
# \begin{align*}
# \begin{bmatrix}
# F_1^{(c)} \\
# F_2^{(c)}
# \end{bmatrix}
# =
# C_{\text{damper}}
# \begin{bmatrix}
# \dot{z}_1 \\
# \dot{z}_2
# \end{bmatrix},
# \end{align*}
#
# where the damper-induced damping matrix is defined as
#
# \begin{align*}
# C_{\text{damper}}
# =
# c_{\text{damper}}
# \begin{bmatrix}
# \psi_1^2\!\left(l_{\text{damper}}\right) &
# \psi_1\!\left(l_{\text{damper}}\right)\psi_2\!\left(l_{\text{damper}}\right) \\
# \psi_1\!\left(l_{\text{damper}}\right)\psi_2\!\left(l_{\text{damper}}\right) &
# \psi_2^2\!\left(l_{\text{damper}}\right)
# \end{bmatrix}.
# \end{align*}
#
# The dynamic and inertial effects of the spring, damper, and external exciter can now be incorporated into the reduced 2-DOF system.

# %% [markdown]
# The final reduced system equation is given by:
#
# $$
# (\mathbf{M_\text{beam}} + \mathbf{M_\text{spring}} + \mathbf{M_\text{damper}} + \mathbf{M_\text{exciter}}) \mathbf{\ddot{z}} + (\mathbf{C_\text{beam} + \mathbf{C_{\text{damper}}}})\mathbf{\dot{z}} + \mathbf{K_{\text{beam}}}\mathbf{z} = \mathbf{F_{\text{exciter}}}
# $$
#
# where $\mathbf{M}, \mathbf{C}, \mathbf{K} \in \mathbb{M_{2x2}}$ and $\mathbf{F}, \mathbf{z} \in \mathbb{R_2}$

# %%
from dataclasses import dataclass

@dataclass(frozen=True)
class BeamProps:
    b: float = 0.025
    h: float = 0.01
    m_beam: float = 1.65
    L: float = 0.815
    E: float = 2e11

    @property
    def A(self) -> float:
        return self.b * self.h

    @property
    def I(self) -> float:
        return self.b * (self.h ** 3) / 12.0

    @property
    def rho(self) -> float:
        return self.m_beam / (self.A * self.L)


@dataclass(frozen=True)
class SpringProps:
    k_spring: float = 3800.0
    l_spring: float = 0.75
    m_spring: float = 0.388
    m_fixed: float = 0.009

    @property
    def k_theta(self) -> float:
        return self.k_spring * (self.l_spring ** 2)


@dataclass(frozen=True)
class DamperProps:
    l_damper: float = 0.2
    m_damper: float = 0.53


@dataclass(frozen=True)
class ExciterProps:
    m_exciter: float = 4.2
    l_exciter: float = 0.4


# ===== create objects =====
beam = BeamProps()
spring = SpringProps()
damper = DamperProps()
exciter = ExciterProps()

b = beam.b
h = beam.h
A = beam.A
m_beam = beam.m_beam
l_beam = beam.L
E = beam.E
I = beam.I
rho = beam.rho

k_spring = spring.k_spring
l_spring = spring.l_spring
m_spring = spring.m_spring
m_fixed = spring.m_fixed
k_theta = spring.k_theta

l_damper = damper.l_damper
m_damper = damper.m_damper

m_exciter = exciter.m_exciter
l_exciter = exciter.l_exciter

# %%
# ================= Find first two betas =================
roots = locate_beta_values(l_beam, E*I, k_theta, num_modes=2, beta_limit=50.0)
beta1, beta2 = roots
print(f"beta1 = {beta1:.4f}, beta2 = {beta2:.4f}")

# ================= Mode shape function =================
def psi(x, beta, l_beam, EI, k_theta):
    A, B, C, D = extract_mode_coeffs(beta, l_beam, EI, k_theta)
    return A*np.cosh(beta*x) + B*np.sinh(beta*x) + C*np.cos(beta*x) + D*np.sin(beta*x)

# ================= Evaluate psi at specific points =================
points = {
    "l_spring": l_spring,
    "l_damper": l_damper,
    "l_exciter": l_exciter
}

for name, x0 in points.items():
    v1 = psi(x0, beta1, l_beam, E*I, k_theta)
    v2 = psi(x0, beta2, l_beam, E*I, k_theta)
    print(f"psi1({name}) = {v1:.4f}, psi2({name}) = {v2:.4f}")

# ================= Modal masses =================
def modal_mass(beta):
    integrand = lambda x: rho * A * (psi(x, beta, l_beam, E*I, k_theta)**2)
    m, _ = quad(integrand, 0, l_beam)
    return m

m1 = modal_mass(beta1)
m2 = modal_mass(beta2)

# ================= Natural frequencies (Beam Only) =================
omega1 = (beta1**2) * np.sqrt((E*I) / (rho*A))
omega2 = (beta2**2) * np.sqrt((E*I) / (rho*A))

print(f"Modal mass m1 = {m1:.4f} kg, m2 = {m2:.4f} kg")
print(f"Natural frequencies for beam alone: omega1 = {omega1:.4f} rad/s, omega2 = {omega2:.4f} rad/s")
# Out:
# beta1 = 1.9417, beta2 = 5.1942
# psi1(l_spring) = -1.3706, psi2(l_spring) = -0.8789
# psi1(l_damper) = -0.2491, psi2(l_damper) = 0.7102
# psi1(l_exciter) = -0.6133, psi2(l_exciter) = 0.8923
# Modal mass m1 = 1.0818 kg, m2 = 0.7688 kg
# Natural frequencies for beam alone: omega1 = 54.0892 rad/s, omega2 = 387.0553 rad/s
